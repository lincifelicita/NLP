# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## Character Tokenizer

# %%
text = "Hello World"
lst = [x for x in text]
print(lst)
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd']

# %% [markdown]
# ## Word Tokenizer

# %%
from nltk.tokenize import word_tokenize

# %%
text = "hello there! You're welcome to N.L.P's and San Francisco."
print(word_tokenize(text))
# Out:
# ['hello', 'there', '!', 'You', "'re", 'welcome', 'to', 'N.L.P', "'s", 'and', 'San', 'Francisco', '.']

# %% [markdown]
# ## Sentence Tokenizer

# %%
from nltk.tokenize import sent_tokenize

# %%
text = "hello there! You're welcome to U.S.A. and San Francisco. This is the best!"
print(sent_tokenize(text))
# Out:
# ['hello there!', "You're welcome to U.S.A. and San Francisco.", 'This is the best!']

# %% [markdown]
# ## White space Tokenizer

# %%
from nltk.tokenize import WhitespaceTokenizer

# %%
text = "hello there! \nYou're welcome to U.S.A. and San Francisco. \tThis is   the best!"
wt = WhitespaceTokenizer()
print(wt.tokenize(text))
# Out:
# ['hello', 'there!', "You're", 'welcome', 'to', 'U.S.A.', 'and', 'San', 'Francisco.', 'This', 'is', 'the', 'best!']

# %% [markdown]
# ## Word Punctuation Tokenizer

# %%
from nltk.tokenize import WordPunctTokenizer

# %%
text = "hello there! \nYou're welcome to U.S.A. and San Francisco. \tThis is   the best!"
wt = WordPunctTokenizer()
print(wt.tokenize(text))
# Out:
# ['hello', 'there', '!', 'You', "'", 're', 'welcome', 'to', 'U', '.', 'S', '.', 'A', '.', 'and', 'San', 'Francisco', '.', 'This', 'is', 'the', 'best', '!']

# %%
import re

# %%
text = "hello-hi-dhanya,how are you"
re.sub("\W+", " ", text)
# Out:
# 'hello hi dhanya how are you'

# %% [markdown]
# ## RegEx Tokenizer

# %%
from nltk.tokenize import RegexpTokenizer

# %%
text = "hello-hi-dhanya,how are you"
wt = RegexpTokenizer(r"\w+")
print(wt.tokenize(text))
# Out:
# ['hello', 'hi', 'dhanya', 'how', 'are', 'you']

# %%
print(" ".join(wt.tokenize(text)))
# Out:
# hello hi dhanya how are you

# %%
import pandas as pd
from nltk.tokenize import word_tokenize
df = pd.DataFrame({'Phrases': ['The greatest glory in living lies not in never falling, but in rising every time we fall.',
'The way to get started is to quit talking and begin doing.',
'If life were predictable it would cease to be life, and be without flavor.',
"If you set your goals ridiculously high and it's a failure, you will fail above everyone else's success."]})
df['tokenized'] = df.apply(lambda row: nltk.word_tokenize(row['Phrases']), axis=1)
df.head()
# Out:
#                                              Phrases  \
# 0  The greatest glory in living lies not in never...
# 1  The way to get started is to quit talking and ...
# 2  If life were predictable it would cease to be ...
# 3  If you set your goals ridiculously high and it...
#
#                                            tokenized
# 0  [The, greatest, glory, in, living, lies, not, ...
# 1  [The, way, to, get, started, is, to, quit, tal...
# 2  [If, life, were, predictable, it, would, cease...
# 3  [If, you, set, your, goals, ridiculously, high...

# %%
text="This is the first line of text.\nThis is the second line of text."
print(text)
print(text.split('\n')) #Spliting the text by '\n'.
print(text.split('\t')) #Spliting the text by '\t'.
print(text.split('s')) #Spliting by charecter 's'.
print(text.split()) #Spliting the text by space.
print(word_tokenize(text)) #Tokenizing by using word
# Out:
# This is the first line of text.
# This is the second line of text.
# ['This is the first line of text.', 'This is the second line of text.']
# ['This is the first line of text.\nThis is the second line of text.']
# ['Thi', ' i', ' the fir', 't line of text.\nThi', ' i', ' the ', 'econd line of text.']
# ['This', 'is', 'the', 'first', 'line', 'of', 'text.', 'This', 'is', 'the', 'second', 'line', 'of', 'text.']
# ['This', 'is', 'the', 'first', 'line', 'of', 'text', '.', 'This', 'is', 'the', 'second', 'line', 'of', 'text', '.']

# %% [markdown]
# ## Line Tokenizer

# %%
from nltk.tokenize import LineTokenizer

# %%
text = "hello world.\n Hi this \nis dhanya"
wt = LineTokenizer()
print(wt.tokenize(text))
# Out:
# ['hello world.', ' Hi this ', 'is dhanya']

# %% [markdown]
# ## Tweet Tokenizer

# %%
from nltk.tokenize import TweetTokenizer

# %%
text = "hello world.\n Hi this \nis soooo coooool Damn:) #cool"
wt = TweetTokenizer()
print(wt.tokenize(text))
# Out:
# ['hello', 'world', '.', 'Hi', 'this', 'is', 'soooo', 'coooool', 'Damn', ':)', '#cool']

# %% [markdown]
# ## Space Tokenizer

# %%
from nltk.tokenize import SpaceTokenizer

# %%
text = "hello world.\n Hi this \nis so    cool !"
wt = SpaceTokenizer()
print(wt.tokenize(text))
# Out:
# ['hello', 'world.\n', 'Hi', 'this', '\nis', 'so', '', '', '', 'cool', '!']

# %% [markdown]
# ## Spacy Tokenizer

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp("Hello world! Welcome to U.S.A")
for token in doc:
  print(token.text)
# Out:
# Hello
# world
# !
# Welcome
# to
# U.S.A

# %%
doc = nlp("Don't")
for token in doc:
  print(token.text)
# Out:
# Do
# n't

# %%
doc = nlp("Let's go to U.S.A")
for token in doc:
  print(token.text)
# Out:
# Let
# 's
# go
# to
# U.S.A

# %%
from spacy.tokenizer import Tokenizer
from spacy.lang.en import English
nlp = English()
# Creating a blank Tokenizer with just the English vocab
tokenizer = Tokenizer(nlp.vocab)
tokens = tokenizer("Let's go to N.Y.")
print("Blank tokenizer",end=" : ")
for token in tokens:
    print(token,end=', ')
# Out:
# Blank tokenizer : Let's, go, to, N.Y.,

# %%
# Construction 2
from spacy.lang.en import English
nlp = English()
# Creating a Tokenizer with the default settings for English
tokenizer = nlp.tokenizer
tokens = tokenizer("Let's go to N.Y.")
print("\nDefault tokenizer",end=' : ')
for token in tokens:
    print(token,end=', ')
# Out:
# Default tokenizer : Let, 's, go, to, N.Y.,

# %%
from spacy.symbols import ORTH
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp("ViratKohli is the world's best batsman")
for token in doc:
    print(token,end=', ')
# Out:
# ViratKohli, is, the, world, 's, best, batsman,

# %%
special_case = [{ORTH: "Virat"}, {ORTH: "Kohli"}]
nlp.tokenizer.add_special_case("ViratKohli", special_case)
doc = nlp("ViratKohli is the world's best batsman")
for token in doc:
    print(token,end=', ')
# Out:
# Virat, Kohli, is, the, world, 's, best, batsman,

# %%
special_case = [{ORTH: "give"}, {ORTH: "me"}]
nlp.tokenizer.add_special_case("gimme", special_case)
doc = nlp("Please gimme the book")
for token in doc:
    print(token,end=', ')
# Out:
# Please, give, me, the, book,

# %%
nlp = English()
text = "Let's don't move to L.A."
doc = nlp(text)
tok_exp = nlp.tokenizer.explain(text)
for t in tok_exp:
  print(t[1], "\t", t[0])
# Out:
# Let 	 SPECIAL-1
# 's 	 SPECIAL-2
# do 	 SPECIAL-1
# n't 	 SPECIAL-2
# move 	 TOKEN
# to 	 TOKEN
# L.A. 	 TOKEN

# %%
print(doc)
# Out:
# I'm having a good time!!!

# %%
doc = nlp("I'm having a good time!!!")
for token in doc:
  print(token.text, end=' | ')
# Out:
# I | 'm | having | a | good | time | ! | ! | ! |

# %%
doc1 = nlp(u"We're here to help! send mail to abc@gmail.com or visit www.abc.com")
for token in doc1:
  print(token.text, end=' | ')
# Out:
# We | 're | here | to | help | ! | send | mail | to | abc@gmail.com | or | visit | www.abc.com |

# %%
doc2 = nlp(u"A 5km ola cab ride costs $10.00")
for token in doc2:
  print(token.text, end=' | ')
# Out:
# A | 5 | km | ola | cab | ride | costs | $ | 10.00 |

# %%
doc2[2:5]
# Out:
# km ola cab

# %%
doc2[-4:]
# Out:
# ride costs $10.00

# %%
doc3 = nlp(u"my dinner was horrible")
doc4 = nlp(u"my dinner was good")
doc3[3] = doc4[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-bc2ceeee1abc> in <module>()
#       1 doc3 = nlp(u"my dinner was horrible")
#       2 doc4 = nlp(u"my dinner was good")
# ----> 3 doc3[3] = doc4[3]
#
# TypeError: 'spacy.tokens.doc.Doc' object does not support item assignment

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc5 = nlp(u"Apple to build a Hong Kong factory for $6 million")
for token in doc5:
  print(token.text, end=' | ')
# Out:
# Apple | to | build | a | Hong | Kong | factory | for | $ | 6 | million |

# %%
for ent in doc5.ents:
  print(ent.text+ '-'+ ent.label_+ '-'+ str(spacy.explain(ent.label_)))
# Out:
# Apple-ORG-Companies, agencies, institutions, etc.
# Hong Kong-GPE-Countries, cities, states
# $6 million-MONEY-Monetary values, including unit

# %%
doc6 = nlp(u"This apple looks delicious")
for ent in doc6.ents:
  print(ent.text+ '-'+ ent.label_+ '-'+ str(spacy.explain(ent.label_)))

# %%
doc7 = nlp("autonomous cars insurance liability ")
for i in doc7.noun_chunks:
  print(i)
# Out:
# autonomous cars insurance liability

# %%
from spacy import displacy
displacy.render(doc5, style='dep',jupyter=True, options={'distance':110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="bedabf7f10f54da59569e4cf0640eb0d-0" class="displacy" width="1260" height="412.0" direction="ltr" style="max-width: none; height: 412.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">build</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">Hong</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">Kong</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">factory</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">6</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">million</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bedabf7f10f54da59569e4cf0640eb0d-0-0" stroke-width="2px" d="M180,277.0 C180,222.0 250.0,222.0 250.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bedabf7f10f54da59569e4cf0640eb0d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180,279.0 L172,267.0 188,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bedabf7f10f54da59569e4cf0640eb0d-0-1" stroke-width="2px" d="M70,277.0 C70,167.0 255.0,167.0 255.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bedabf7f10f54da59569e4cf0640eb0d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">relcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M255.0,279.0 L263.0,267.0 247.0,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bedabf7f10f54da59569e4cf0640eb0d-0-2" stroke-width="2px" d="M400,277.0 C400,112.0 700.0,112.0 700.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bedabf7f10f54da59569e4cf0640eb0d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400,279.0 L392,267.0 408,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bedabf7f10f54da59569e4cf0640eb0d-0-3" stroke-width="2px" d="M510,277.0 C510,222.0 580.0,222.0 580.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bedabf7f10f54da59569e4cf0640eb0d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M510,279.0 L502,267.0 518,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bedabf7f10f54da59569e4cf0640eb0d-0-4" stroke-width="2px" d="M620,277.0 C620,222.0 690.0,222.0 690.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bedabf7f10f54da59569e4cf0640eb0d-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M620,279.0 L612,267.0 628,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bedabf7f10f54da59569e4cf0640eb0d-0-5" stroke-width="2px" d="M290,277.0 C290,57.0 705.0,57.0 705.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bedabf7f10f54da59569e4cf0640eb0d-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M705.0,279.0 L713.0,267.0 697.0,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bedabf7f10f54da59569e4cf0640eb0d-0-6" stroke-width="2px" d="M290,277.0 C290,2.0 820.0,2.0 820.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bedabf7f10f54da59569e4cf0640eb0d-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M820.0,279.0 L828.0,267.0 812.0,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bedabf7f10f54da59569e4cf0640eb0d-0-7" stroke-width="2px" d="M950,277.0 C950,167.0 1135.0,167.0 1135.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bedabf7f10f54da59569e4cf0640eb0d-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">quantmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M950,279.0 L942,267.0 958,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bedabf7f10f54da59569e4cf0640eb0d-0-8" stroke-width="2px" d="M1060,277.0 C1060,222.0 1130.0,222.0 1130.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:hr

# %%
doc = nlp(u'Over the last quarter Apple sold nearly 20 thousand iPods for a profit of $6 million.')
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 20 thousand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPods
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  for a profit of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# .</div></span>

# %%
text = "I like bananabread breadbanana breadbananabread"
print([t.text for t in nlp(text)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-8ae4c3320fe7> in <module>()
#       1 text = "I like bananabread breadbanana breadbananabread"
# ----> 2 print([t.text for t in nlp(text)])
#
# NameError: name 'nlp' is not defined

# %%
prefixes = ("banana",)+nlp.Defaults.prefixes
suffixes = ("banana",)+nlp.Defaults.suffixes
infixes = ("banana",)+nlp.Defaults.infixes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-96f131a0c2c7> in <module>()
# ----> 1 prefixes = ("banana",)+nlp.Defaults.prefixes
#       2 suffixes = ("banana",)+nlp.Defaults.suffixes
#       3 infixes = ("banana",)+nlp.Defaults.infixes
#
# NameError: name 'nlp' is not defined

# %%
prefix_regex = spacy.util.compile_prefix_regex(prefixes)
suffix_regex = spacy.util.compile_suffix_regex(suffixes)
infix_regex = spacy.util.compile_infix_regex(infixes)

# %%
nlp.tokenizer.prefix_search = prefix_regex.search
nlp.tokenizer.suffix_search = suffix_regex.search
nlp.tokenizer.infix_finditer = infix_regex.finditer

# %%
print([t.text for t in nlp(text)])
# Out:
# ['I', 'like', 'banana', 'bread', 'bread', 'banana', 'bread', 'banana', 'bread']

# %%
doc = nlp("hello-[ world] #. :/")
print([t.text for t in doc])
# Out:
# ['hello-', '[', 'world', ']', '#', '.', ':/']

# %%
suffixes = list(nlp.Defaults.suffixes)
suffixes.remove("\\[")
suffix_regex = spacy.util.compile_suffix_regex(suffixes)
nlp.tokenizer.suffix_search = suffix_regex.search

# %%
doc = nlp("hello-[ world] $. :)")
print([t.text for t in doc])
# Out:
# ['hello-[', 'world', ']', '$', '.', ':)']
